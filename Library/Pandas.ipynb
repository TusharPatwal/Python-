# %%
import numpy as np
import pandas as pd

# %%
# creating a csv file with dictionary in python
dict1 = {
    "Name":['tushar', 'pranjal', 'ansh', 'sahil'],
    "Marks":[92,78,98,43],
    "City":['delhi','up','kolkata','chennai']
}

# %%
# DataFrame = A Pandas DataFrame is a 2 dimensional data 
# structure, like a 2 dimensional array, or a table with rows 
# and columns.
df = pd.DataFrame(dict1)

# %%
df
# Out:
#       Name  Marks     City
# 0   tushar     92    delhi
# 1  pranjal     78       up
# 2     ansh     98  kolkata
# 3    sahil     43  chennai

# %%
df.to_csv('details.csv') # to convert data into .csv file(excel)

# %%
df.to_csv('details_false_index.csv',index = False) # it will not show index

# %%
df.head(2) # it will show top 2 rows
# Out:
#       Name  Marks   City
# 0   tushar     92  delhi
# 1  pranjal     78     up

# %%
df.tail(2) # it will show bottom 2 rows
# Out:
#     Name  Marks     City
# 2   ansh     98  kolkata
# 3  sahil     43  chennai

# %%
df.describe() # it will show most of the mathematical operation on data
# Out:
#            Marks
# count   4.000000
# mean   77.750000
# std    24.635679
# min    43.000000
# 25%    69.250000
# 50%    85.000000
# 75%    93.500000
# max    98.000000

# %%
tushar = pd.read_csv('tushar.csv') # it will read csv file

# %%
tushar
# Out:
#    Unnamed: 0.1  Unnamed: 0  Roll Class     Name  Marks
# 0             0           0     1     A   Tushar    100
# 1             1           1     2     B    Sahil     88
# 2             2           2     3     C  Pranjal     77
# 3             3           3     4     D     Ansh     66
# 4             4           4     5    EA  Devansh     55
# 5             5           5     6    EB   Kartik     44

# %%
tushar['Marks'][0] = 100 # it will change value of element
# Out:
# C:\Users\Tushar\AppData\Local\Temp\ipykernel_13308\2123266784.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tushar['Marks'][0] = 100 # it will change value of element

# %%
tushar
# Out:
#    Unnamed: 0.1  Unnamed: 0  Roll Class     Name  Marks
# 0             0           0     1     A   Tushar    100
# 1             1           1     2     B    Sahil     88
# 2             2           2     3     C  Pranjal     77
# 3             3           3     4     D     Ansh     66
# 4             4           4     5    EA  Devansh     55
# 5             5           5     6    EB   Kartik     44

# %%
tushar.to_csv('tushar.csv') # to append change in csv

# %%
tushar.index = ['first','second','third','fourth','fivth','sixth']

# %%
tushar
# Out:
#         Unnamed: 0.1  Unnamed: 0  Roll Class     Name  Marks
# first              0           0     1     A   Tushar    100
# second             1           1     2     B    Sahil     88
# third              2           2     3     C  Pranjal     77
# fourth             3           3     4     D     Ansh     66
# fivth              4           4     5    EA  Devansh     55
# sixth              5           5     6    EB   Kartik     44

# %%
# reading csv files with pandas

# df = pd.read_csv(r"C:\Users\Tushar\Downloads\countries of the world.csv", header=None,names=['Country','Region'])
df = pd.read_csv(r"C:\Users\Tushar\Downloads\countries of the world.csv")
df.head()
# Out:
#            Country                               Region
# 0     Afghanistan         ASIA (EX. NEAR EAST)
# 1         Albania   EASTERN EUROPE
# 2         Algeria   NORTHERN AFRICA
# 3  American Samoa   OCEANIA
# 4         Andorra   WESTERN EUROPE

# %%
# reading txt files with pandas

# df = pd.read_csv(r"C:\Users\Tushar\Downloads\countries of the world.txt", sep='\t')

df = pd.read_table(r"C:\Users\Tushar\Downloads\countries of the world.txt")
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
# reading json files with pandas

df = pd.read_json(r"C:\Users\Tushar\Downloads\json_sample.json")
df
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
# reading excel file with pandas

df = pd.read_excel(r"C:\Users\Tushar\Downloads\world_population_excel_workbook.xlsx")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
qty = 25
print(f'I buy A4 sheet packet at {qty*18}', end="")
print(f" & sell them at ",end='')
print(qty*30)
# Out:
# I buy A4 sheet packet at 450 & sell them at 750

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.shape
# Out:
# (234, 17)

# %%
df.head(10)
# Out:
#    Rank CCA3              Country           Capital      Continent  \
# 0    36  AFG          Afghanistan             Kabul           Asia
# 1   138  ALB              Albania            Tirana         Europe
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda    Saint Johnâ€™s  North America
# 8    33  ARG            Argentina      Buenos Aires  South America
# 9   140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771         38972230         33753499         28189672
# 1          2842321          2866849          2882481          2913399
# ...

# %%
df.tail(10)
# Out:
#      Rank CCA3            Country       Capital      Continent  \
# 224    43  UZB         Uzbekistan      Tashkent           Asia
# 225   181  VUT            Vanuatu     Port-Vila        Oceania
# 226   234  VAT       Vatican City  Vatican City         Europe
# 227    51  VEN          Venezuela       Caracas  South America
# 228    16  VNM            Vietnam         Hanoi           Asia
# 229   226  WLF  Wallis and Futuna      Mata-Utu        Oceania
# 230   172  ESH     Western Sahara     El AaiÃºn         Africa
# 231    46  YEM              Yemen         Sanaa           Asia
# 232    63  ZMB             Zambia        Lusaka         Africa
# 233    74  ZWE           Zimbabwe        Harare         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 224         34627652         33526656         30949417         28614227
# 225           326740           311685           276438           245453
# ...

# %%
df['Rank']
# Out:
# 0       36
# 1      138
# 2       34
# 3      213
# 4      203
#       ...
# 229    226
# 230    172
# 231     46
# 232     63
# 233     74
# Name: Rank, Length: 234, dtype: int64

# %%
df.loc[224]
# Out:
# Rank                                   43
# CCA3                                  UZB
# Country                        Uzbekistan
# Capital                          Tashkent
# Continent                            Asia
# 2022 Population                  34627652
# 2020 Population                  33526656
# 2015 Population                  30949417
# 2010 Population                  28614227
# 2000 Population                  24925554
# 1990 Population                  20579100
# 1980 Population                  15947129
# 1970 Population                  12011361
# Area (kmÂ²)                        447400
# Density (per kmÂ²)                77.3975
# Growth Rate                         1.016
# World Population Percentage          0.43
# Name: 224, dtype: object

# %%
df.iloc[224]
# Out:
# Rank                                   43
# CCA3                                  UZB
# Country                        Uzbekistan
# Capital                          Tashkent
# Continent                            Asia
# 2022 Population                  34627652
# 2020 Population                  33526656
# 2015 Population                  30949417
# 2010 Population                  28614227
# 2000 Population                  24925554
# 1990 Population                  20579100
# 1980 Population                  15947129
# 1970 Population                  12011361
# Area (kmÂ²)                        447400
# Density (per kmÂ²)                77.3975
# Growth Rate                         1.016
# World Population Percentage          0.43
# Name: 224, dtype: object
