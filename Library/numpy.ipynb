# %%
import numpy as np

# %%
pip install numpy
# Out:
# ...
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.1/15.8 MB 1.1 MB/s eta 0:00:15
#                                              0.2/15.8 MB 985.7 kB/s eta 0:00:16
#                                              0.2/15.8 MB 985.7 kB/s eta 0:00:16
#                                              0.2/15.8 MB 985.7 kB/s eta 0:00:16
#                                              0.3/15.8 MB 827.5 kB/s eta 0:00:19
#                                              0.3/15.8 MB 827.5 kB/s eta 0:00:19
#                                              0.3/15.8 MB 838.1 kB/s eta 0:00:19
#                                              0.3/15.8 MB 838.1 kB/s eta 0:00:19
#                                              0.3/15.8 MB 838.1 kB/s eta 0:00:19
# ...

# %%
arr = np.array([1,2,3,4,5])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
# creating the numpy array

arr1 = np.array([[1,2],[3,4]])

# dtype in array
arr2 = np.array([1,2,3,4], dtype='f')


print(arr1)
print(arr2)
# Out:
# [[1 2]
#  [3 4]]
# [1. 2. 3. 4.]

# %%
# indexing in numpy array

print(arr1[0])

print(arr[-4])
# Out:
# [1 2]
# 2

# %%
# string type array in numpy

mystr = np.array(['a','b','c','d'], dtype=np.str_)
print(mystr)
# Out:
# ['a' 'b' 'c' 'd']
